# %%
import sys
sys.path.append("../")

from src.recommendations import (
    get_credit_recommendation,
    get_fraud_recommendation,
    get_segment_recommendation,
    get_final_risk_summary
)

# %%
get_credit_recommendation(0.76)
# Out:
# {'default_probability': 0.76,
#  'risk_level': 'High Risk',
#  'decision': 'Reject / Manual Review Required',
#  'recommendation': 'Reject loan application or request collateral/guarantor.'}

# %%
get_fraud_recommendation(0.91)
# Out:
# {'fraud_probability': 0.91,
#  'risk_level': 'Critical Risk',
#  'decision': 'Block Transaction',
#  'recommended_action': 'Block transaction immediately and freeze account temporarily.'}

# %%
get_final_risk_summary(
    default_probability=0.68,
    fraud_probability=0.88,
    segment_name="Suspicious High Risk Customers"
)
# Out:
# {'credit_risk': {'default_probability': 0.68,
#   'risk_level': 'Medium Risk',
#   'decision': 'Manual Review',
#   'recommendation': 'Approve only after manual verification, income proof check, and possible higher interest rate.'},
#  'fraud_risk': {'fraud_probability': 0.88,
#   'risk_level': 'Critical Risk',
#   'decision': 'Block Transaction',
#   'recommended_action': 'Block transaction immediately and freeze account temporarily.'},
#  'customer_segment': {'segment_name': 'Suspicious High Risk Customers',
#   'segment_action': 'Monitor account closely and apply stricter transaction checks.',
#   'business_priority': 'Critical'}}
