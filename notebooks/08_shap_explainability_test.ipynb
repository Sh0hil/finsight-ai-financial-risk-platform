# %%
import src.explainability
print(src.explainability.__file__)
import sys
sys.path.append("../")

from src.explainability import explain_credit_prediction, explain_fraud_prediction
# Out:
# d:\. ML\PROJECT\finsight-ai\notebooks\..\src\explainability.py

# %%
credit_sample = {
    'NAME_CONTRACT_TYPE': 'Cash loans',
    'CODE_GENDER': 'M',
    'FLAG_OWN_CAR': 'Y',
    'FLAG_OWN_REALTY': 'Y',
    'CNT_CHILDREN': 1,
    'AMT_INCOME_TOTAL': 157500.0,
    'AMT_CREDIT': 770292.0,
    'AMT_ANNUITY': 30676.5,
    'AMT_GOODS_PRICE': 688500.0,
    'NAME_INCOME_TYPE': 'Working',
    'NAME_EDUCATION_TYPE': 'Higher education',
    'NAME_FAMILY_STATUS': 'Married',
    'NAME_HOUSING_TYPE': 'House / apartment',
    'DAYS_BIRTH': -13506,
    'DAYS_EMPLOYED': -105,
    'OCCUPATION_TYPE': 'Laborers',
    'CNT_FAM_MEMBERS': 3.0,
    'CREDIT_INCOME_RATIO': 4.8907428571428575,
    'ANNUITY_INCOME_RATIO': 0.1947714285714285,
    'CREDIT_TERM': 0.0398245081086133,
    'DAYS_EMPLOYED_RATIO': 0.0077743225233229
}

# %%
explain_credit_prediction(credit_sample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 explain_credit_prediction(credit_sample)
#
# File d:\. ML\PROJECT\finsight-ai\notebooks\..\src\explainability.py:91, in explain_credit_prediction(input_data, top_n)
#      89 for idx in top_indices:
#      90     feature_name = str(feature_names[idx])
# ---> 91     shap_value = float(shap_values_single[idx])
#      93     impact = "increases risk" if shap_value > 0 else "decreases risk"
#      95     explanations.append({
#      96         "feature": feature_name,
#      97         "shap_value": round(shap_value, 4),
#      98         "impact": impact
#      99     })
#
# TypeError: only length-1 arrays can be converted to Python scalars
